# %%
nombre=input("¿Cual es tu nombrbe?")
# Out:
# ¿Cual es tu nombrbe?Oscar

# %%
nombre
# Out:
# 'Oscar'

# %%
print("hola" ,nombre)
# Out:
# hola Oscar

# %%
print ("Hola " +nombre+ ", Bienvenido.")
# Out:
# Hola Oscar, Bienvenido

# %%
type (nombre)
# Out:
# str

# %%
numero = 100
type (numero)  #int ->integer  numero entero
# Out:
# int

# %%
decimal=3.1416
type(decimal) #Float -> numero decimal
# Out:
# float

# %%
logica=True #verdadero
type(logica) #bool ->booleano ->verdadero o falso
# Out:
# bool

# %%
logica=False #falso
type(logica) #bool -> booleano ->Verdadero o falso
# Out:
# bool

# %%
num1=10
num2=2

# %%
5+11+(12*3)
# Out:
# 52

# %%
num1+num2
# Out:
# 12

# %%
num1-num2
# Out:
# 8

# %%
num1*num2
# Out:
# 20

# %%
num1/num2
# Out:
# 5.0

# %%
print ("Este programa multiplica dos numeros")
num1=int(input("Escribe el primer numero: "))
num2=int(input("Escribe el segundo numero: "))
print("El resultado es {} x {} es {}",format(num1,num2,num1*num2))
# Out:
# Este programa multiplica dos numeros
# Escribe el primer numero: 10
# Escribe el segundo numero: 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-7f85051b4c34> in <module>
#       2 num1=int(input("Escribe el primer numero: "))
#       3 num2=int(input("Escribe el segundo numero: "))
# ----> 4 print("El resultado es {} x {} es {}",format(num1,num2,num1*num2))
#       5
#
# TypeError: format() takes at most 2 arguments (3 given)

# %%
print ("El resultado es de: " +str(+int_num1))
# Out:
# El resultado es de: 10

# %%
print("El resultado de {} X {} es {}".format(int_num1,int_num2,resultado))
# Out:
# El resultado de 10 X 10 es 100

# %%
print("Esta es una calculadora")
print("Elije el tipo de operacion del menu")
print ("1. Sumar")
print ("2. Restar")
print ("3. Multiplicar")
print ("4. Dividir")
res=input("¿Que quieres hacer?")
num1=float(input("Escribe el primer numero: "))
num2=float(input("Escribe el segundo numero: "))
if res=="sumar":
  print("{} + {} = {} ".format(num1,num2,num1+num2))
elif res=="restar":
  print("{} - {} = {} ".format(num1,num2,num1-num2))
elif res== "multiplicar":
  print("{} * {} = ".format(num1,num2,num1*num2))
elif res=="dividir":
  print("{} / {} = ".format(num1,num2,num1/num2))
else: 
  print("comando no valido")

print("El resultado es: 3")
# Out:
# Esta es una calculadora
# Elije el tipo de operacion del menu
# 1. Sumar
# 2. Restar
# 3. Multiplicar
# 4. Dividir
# ¿Que quieres hacer?sumar
# Escribe el primer numero: 10
# Escribe el segundo numero: 10
# 10.0 + 10.0 =
# El resultado es:

# %%
#seleccion "if" "elif" y "else"
if 10>5:
  print("verdadero")
else: 
  print("Falso")

# %%
#seleccion "if" "elif" y "else"
if 1>5:
  print("verdadero")
else: 
  print("Falso")
# Out:
# Falso

# %%
var= "Oscar"
if var=="Daniel" :
  print("Eres Daniel)")
elif var == "Oscar":
  print("Eres Oscar")
else:
  print("No eres Daniel, ni Oscar")
# Out:
# Eres Oscar

# %%
num1=10
num2=30
if num1==num2:
  print("Son iguales")
elif num1>num2:
  print("El primer es mayor")
elif

# %%
num1=10
num2=11
if num1!=num2:
  print("No son iguales")
else:
  print("Son iguales")
# Out:
# No son iguales

# %%
num1=9
num2=10
if num1<=num2:
  print("El primero es menor o igual")
# Out:
# El primero es menor o igual

# %%
num1=10
num2=10
if num1!=num2:
  print("Son diferentes")
if num1>=num2:
  print("El primero es mayor o igual que el segundo")
if num1==num2:
  print("Son iguales")
else:
  print("Ninguna condicion")
# Out:
# El primero es mayor o igual que el segundo
# Son iguales

# %%
num1=10
num2=10
elif num1==num2:
  print("")

# %%
usuario_db="Oscar"
contraseña_db="qwerty"
print("Log in")
usuario_ingresado=input("Nombres de usuario:")
contraseña_ingresada=input("Contraseña: ")
if usuario_ingresado==usuario_db:
  print("usuario encontrado")
  if contraseña_ingresada==contraseña_db:
   print("La contraseña no coincide")
  k print("Entraste al sistema")
  else:
    print("La contraseña no coincide")
else:
  print("Usuario no encontrado")
# Out:
# Log in
# Nombres de usuario:Oscar
# Contraseña: qwerty
# usuario encontrado
# La contraseña no coincide
# Entraste al sistema
