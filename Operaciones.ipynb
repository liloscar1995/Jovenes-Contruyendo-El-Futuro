# %%
limite_inf=int(input('¿Cual quieres que sea tu limite inferior? '))
limite_sup=int(input('¿Cual quieres que sea tu limite superior? '))
i=0
lista=[]
for i in range(limite_inf,limite_sup+1):
  if i%3==0:
    lista.append(i)
    print(lista)

# %%
lista

# %%
pares=[]
for i in lista:
  if i%2==0:
    pares.append(i)
    print(pares)

# %%
pares
