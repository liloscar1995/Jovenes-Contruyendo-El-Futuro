# %%
from cmath import sqrt     #Deja calcular i y convierte el resultado a complejo.

# %%
def funcion_cuadratica(a,b,c):
  x1=  (-b+sqrt(b**2-4*a*c))/(2*a)
  x2= (-b-sqrt(b**2-4*a*c))/(2*a)
  return x1,x2

# %%
print("este programa resulve ecuaciones cuadraticas")
print("De la forma ax**2+bx+c=0")
a=float(input("Escribe el valor de a:"))
b=float(input("Escribe el valor de b:"))
c=float(input("Escribe el valor de c:"))
x1,x2=funcion_cuadratica(a,b,c)
print("El resultado es: ")
print("x1={}" .format(x1))
print("x1={}" .format(x1))
# Out:
# este programa resulve ecuaciones cuadraticas
# De la forma ax**2+bx+c=0
# Escribe el valor de a:1
# Escribe el valor de b:4
# Escribe el valor de c:5
# El resultado es:
# x1=(-2+1j)
# x1=(-2+1j)
